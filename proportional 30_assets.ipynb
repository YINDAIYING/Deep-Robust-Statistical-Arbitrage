# %%
# -*- coding: utf-8 -*-
"""10_assets.ipynb（副本）（副本）

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1kxIJV8jXD29NQ0FjAot1oi0BCvU1Nc6G
"""

# -*- coding: utf-8 -*-
"""example2_30_assets_250_iter

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1BX7F9wRo8AW2cpT_GLRUl-ivazSf-39_
"""

# -*- coding: utf-8 -*-
"""example2_10_assets

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1U_sngHWcXr_iGAwttgqs7sdp6jSNW-zC
"""

#import necessary libraries
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.nn.init as init
import json
import time
import os
import random

#read uploaded csv files
files = sorted([file for file in os.listdir() if file[-3:]=='csv'])

#create a list of dataframes and check their time length 
data_frames = []
for i in range(len(files)):
  file = files[i]
  temp = pd.read_csv(file)
  temp = temp[['Date','Close']]
  temp.columns = ['Date','Close'+str(i)]
  temp.dropna()
  data_frames.append(temp)

z = len(files) #number of assets

#merge all assets into one dataframe
date = data_frames[0]['Date']
date_numerate = ['Close'+str(i)  for i in range(z)]
df = pd.concat(data_frames, axis = 1)[date_numerate]
df['Date'] = date
df = df[['Date']+date_numerate]
df['Date'] = date

test_begin_day = 4000
test_end_day = 5200

#select 5 assets from those uploaded
asset_list = [np.array(df['Close'+str(i)])[:5200] for i in range(z)]

plt.figure()
for i in range(z):
  plt.plot(asset_list[i])

def get_slice_array1(i):
  temp = np.tile(np.arange(i+1), z)
  return temp+np.repeat(np.arange(z),i+1)*8

def get_slice_array2():
  temp = np.tile(np.arange(1,9), z)
  return temp+np.repeat(np.arange(z),8)*10

def get_slice_array3():
  temp = np.tile(np.arange(1,10), z)
  return temp+np.repeat(np.arange(z),9)*10

def beta(x):
    return torch.pow(F.relu(x),2)

# def get_random_partition(stock_mins, stock_maxs, num_sets, discrete = True):
#     partition = np.zeros((num_sets, 2*z))
#     stocks_len = (stock_maxs-stock_mins)/grids
#     for k in range(num_sets):
#       if discrete:
#         lower = np.random.randint(0, grids, size=z)
#         gap = np.random.randint(1, grids-lower+1, size=z)
#         partition[k,:] = np.repeat(stock_mins,2)
#         partition[k,::2] += lower*stocks_len
#         partition[k,1::2] += (lower+gap)*stocks_len
#       else:
#         lower = np.random.uniform(low = stock_mins, high = stock_maxs)
#         upper = np.random.uniform(low = lower, high = stock_maxs)
#         partition[k,::2] = lower
#         partition[k,1::2] = upper
#     return partition

def get_random_partition(stock_mins, stock_maxs, num_sets, discrete = True):
    partition = np.zeros((num_sets, 2*z))
    stocks_len = (stock_maxs-stock_mins)/grids
    for k in range(num_sets):
      if discrete:
        lower = np.random.randint(0, grids, size=z)
        gap = np.random.randint(1, grids-lower+1, size=z)
        partition[k,:] = np.repeat(stock_mins,2)
        partition[k,::2] += lower*stocks_len
        partition[k,1::2] += (lower+gap)*stocks_len
      else:
        lower = np.random.uniform(low = stock_mins, high = stock_maxs)
        upper = stock_maxs
        partition[k,::2] = lower
        partition[k,1::2] = upper
    return partition

def get_indicator_matrix(partition, S_n):
    #print(partition, S_n)
    B = partition.shape[0]
    indicator_matrix = np.zeros((len(S_n), 2**B))
    for i in range(len(S_n)):
      temp = np.ones(B, dtype=bool)
      for j in range(z):
        temp = temp&(partition[:,2*j]<S_n[i,j])
      temp = temp.flatten()
      temp = temp.astype(int)
      pos = int(np.array2string(temp, formatter={'int':lambda x: bin(x)})[1:-1].replace(' ','')[2::3],2)
      indicator_matrix[i][pos]=1
    return torch.FloatTensor(indicator_matrix)

def get_frac_vector(P_tau_tilde, indicator_matrix):
    #get input data for neural network
    net_input = P_tau_tilde[:,get_slice_array2()]
    #perform forward propagation to obtain deltas for each asset
    delta_list, c = net(net_input)
    h_value_trans = 0
    h_value_pnl = 0
    #calculate the loss function summation
    for i in range(z):
      delta = delta_list[i]
      h_value_trans += trans_cost * torch.abs(P_tau_tilde[:,10*i:10*i+10] * torch.cat((delta[:,:1], delta[:,1:]-delta[:,:-1], delta[:,-1:]), 1)).sum(axis = 1)
      h_value_pnl += ((P_tau_tilde[:,10*i+1:10*i+10]-P_tau_tilde[:,10*i:10*i+9])*delta).sum(axis = 1)
    h_value = -c + h_value_trans - h_value_pnl
    temp = torch.matmul(indicator_matrix.T, h_value)
    indicator_sum = torch.sum(indicator_matrix.T, dim=1)
    indicator_sum = torch.where(indicator_sum.abs() > 0.5, indicator_sum, torch.ones((), device = indicator_sum.device, dtype = indicator_sum.dtype))
    return temp/indicator_sum

def stat_arb_success(stock_test, net):

    f = 0
    gain_list = []
    cost_list = []
    success = []
    
    for i in range(int(len(stock_test[0])/10)):
        
        query_data = np.zeros((1, 8*z))

        for j in range(z):
          query_data[0,8*j:8*(j+1)] = (100*stock_test[j][10*i+1:10*i+9]/stock_test[j][10*i]).reshape(1,-1)

        upper_bound = net(torch.FloatTensor(query_data).cuda())[0]
        upper_bound_list = [delta.detach().cpu().numpy()[0] for delta in upper_bound]

        gain = 0
        cost = 0
        for k in range(z):

          delta = upper_bound_list[k]

          # if i in range(0,200,50):
          #   print("Delta "+str(k+1)+" : ", delta)

          gain += np.dot(delta, stock_test[k][10*i+1:10*i+10]-stock_test[k][10*i:10*i+9])
          cost += trans_cost * np.abs(stock_test[k][10*i:10*i+10] * np.concatenate([np.array([delta[0]]), delta[1:]-delta[:-1], np.array([delta[-1]])])).sum()

        success.append(gain-cost)
        gain_list.append(gain)
        cost_list.append(cost)

        f+=success[-1]
    
    print("Toal Gain:", np.array(gain_list).mean(), "Total Cost:", np.array(cost_list).mean())
    success = np.array(success)
    res = dict()
    res['Gain'] = f
    res['Best'] = round(max(success),2)
    res['Worst'] = round(min(success),2)
    res['Average'] = round(success.mean(),2)
    res['loss_perc'] = round(100*float(np.sum(success<0)/len(success)),2)
    res['gains_perc'] = round(100*float(np.sum(success>0)/len(success)),2)
    res['sharp_ratio'] = round(np.sqrt(252.0/9)*success.mean()/success.std(),3)
    res['sortino_ratio'] = round(np.sqrt(252.0/9)*success.mean()/success[success<0].std(),3)
    return res

def stat_arb_success_buy_and_hold(stock_test):

    f = 0
    gain_list = []
    cost_list = []
    success = []
    
    for i in range(int(len(stock_test[0])/10)):

        gain = 0
        cost = 0

        for k in range(z):

          delta = 10*np.ones(9)
          gain += np.dot(delta, stock_test[k][10*i+1:10*i+10]-stock_test[k][10*i:10*i+9])
          cost += trans_cost * np.abs(stock_test[k][10*i:10*i+10] * np.concatenate([np.array([delta[0]]), delta[1:]-delta[:-1], np.array([delta[-1]])])).sum()
        
        success.append(gain-cost)
        gain_list.append(gain)
        cost_list.append(cost)

        f+=success[-1]
    
    print("Toal Gain:", np.array(gain_list).mean(), "Total Cost:", np.array(cost_list).mean())
    success = np.array(success)
    res = dict()
    res['Gain'] = f
    res['Best'] = round(max(success),2)
    res['Worst'] = round(min(success),2)
    res['Average'] = round(success.mean(),2)
    res['loss_perc'] = round(100*float(np.sum(success<0)/len(success)),2)
    res['gains_perc'] = round(100*float(np.sum(success>0)/len(success)),2)
    res['sharp_ratio'] = round(np.sqrt(252.0/9)*success.mean()/success.std(),3)
    res['sortino_ratio'] = round(np.sqrt(252.0/9)*success.mean()/success[success<0].std(),3)
    return res



class Net_independent(nn.Module):

    def __init__(self, M, z):
        super(Net_independent, self).__init__()
        self.first_layers = nn.ModuleList([nn.Linear(z*i,32*z) for i in range(1,8+1)])
        self.bn_layers = nn.ModuleList([nn.BatchNorm1d(z*i) for i in range(1,8+1)])
        self.second_layers = nn.ModuleList([nn.Linear(32*z,64*z) for i in range(1,8+1)])
        self.third_layers = nn.ModuleList([nn.Linear(64*z,128*z) for i in range(1,8+1)])
        self.fourth_layers = nn.ModuleList([nn.Linear(128*z,z) for i in range(1,8+1)])
        self.c = nn.Parameter(torch.FloatTensor([0]))
        self.delta0_s = nn.Parameter(torch.FloatTensor([0]*z))
        self.M = M

    def forward(self, x):
        output1 = [F.relu(self.first_layers[i](self.bn_layers[i](x[:,get_slice_array1(i)]))) for i in range(8)]
        output2 = [F.relu(self.second_layers[i](output1[i])) for i in range(8)]
        output3 = [F.relu(self.third_layers[i](output2[i])) for i in range(8)]
        deltas = [M*torch.tanh(self.fourth_layers[i](output3[i])) for i in range(8)]
        delta_list = [torch.cat([delta[:,i:i+1] for delta in deltas], axis=1) for i in range(z)]
        return [torch.cat((1*self.delta0_s[i]*torch.ones((x.shape[0],1)).cuda(),delta_list[i]), axis=1) for i in range(z)], 1*self.c


stock_train = [asset[:test_begin_day] for asset in asset_list]
stock_test = [asset[test_begin_day:test_end_day] for asset in asset_list]

N = len(stock_train[0])
n=10-1

P_hat = np.zeros((z*(n+1),N-n))

for j in range(z):
  for i in range(n+1):
    P_hat[i+j*(n+1),:] = stock_train[j][i:N-n+i]

P_hat = torch.FloatTensor(P_hat.T)

S_lower = torch.FloatTensor([100]*z)
S_upper = torch.FloatTensor([-100]*z)
for i in range(z):
  for j in range(1,n+1):
    S_lower[i] = torch.min(S_lower[i], torch.min(P_hat[:,10*i+j]/P_hat[:,10*i]))
    S_upper[i] = torch.max(S_upper[i], torch.max(P_hat[:,10*i+j]/P_hat[:,10*i]))

rescaled_lower_bounds = S_lower*100 - z
rescaled_upper_bounds = S_upper*100 + z

print(rescaled_lower_bounds, rescaled_upper_bounds)

results = {'Average':[], 'Best':[], 'Worst':[], 'loss_perc':[], 'gains_perc':[], 'sharp_ratio':[], 'sortino_ratio':[]}

num_epochs = 100
N_measures = 5
grids = 4
K = 1
trials = 50
epsilon = z
M = 10
trans_cost = 0.0001
pnl = []

#print result of buy and hold strategy
print(stat_arb_success_buy_and_hold(stock_test))

for trial in range(trials):
  np.random.seed(trial)
  torch.manual_seed(trial)
  print("Trial:", trial)
  net = Net_independent(M,z).cuda()
  net.train()
  optimizer = optim.Adam(net.parameters(), lr=1e-4)
  loss_rec = []
  c_rec = []
  for epoch in range(num_epochs):

      if epoch%10==0:
        print("Test at Epoch", epoch)
        net.eval()
        record = stat_arb_success(stock_test, net)
        net.train()
        print(record)

      optimizer.zero_grad()
      total_loss = 0
      partition = get_random_partition(rescaled_lower_bounds, rescaled_upper_bounds, 12, False)
      
      for m in range(N_measures):
          
          #batch_index = np.random.randint(0,P_hat.shape[0],size=batch_size)
          batch_index = np.arange(P_hat.shape[0])

          P_tau_tilde = P_hat.clone()

          for j in range(z):
            P_tau_tilde[:,10*j:10*(j+1)] /= (P_tau_tilde[:,10*j]/100).reshape(-1,1)

          tau_m = torch.FloatTensor(np.random.normal(0,1,(P_hat.shape[0], P_hat.shape[1]-z)))
          U_epsilon = torch.FloatTensor(epsilon * np.random.rand(1))
          tau_tilde = U_epsilon * tau_m/torch.norm(tau_m, p=2, dim=1, keepdim=True)

          P_tau_tilde[:,get_slice_array3()] += tau_tilde

          S_n = P_tau_tilde[:,np.arange(1,z+1)*10-1].numpy()
          S_n = S_n[batch_index]

          indicator_matrix = get_indicator_matrix(partition, S_n).cuda()
          P_tau_tilde = P_tau_tilde.cuda()
          P_tau_tilde = P_tau_tilde[batch_index]

          frac_vector = get_frac_vector(P_tau_tilde, indicator_matrix)
          total_loss += beta(torch.matmul(indicator_matrix, frac_vector)).sum()/len(S_n)

      total_loss = 1*net.c + K * total_loss
      loss_rec.append(total_loss.item())
      c_rec.append(1*net.c.clone().detach().cpu().numpy()[0])
      total_loss.backward()
      optimizer.step()
      with torch.no_grad():
        net.c.clamp_(-M/1, M/1)
        net.delta0_s.clamp_(-M/1, M/1)

  print("Done Training")
  net.eval()
  record = stat_arb_success(stock_test, net)
  print("Result After Training:")
  print(record)

  pnl.append(record)

  plt.figure()
  plt.plot(loss_rec)
  plt.title('Loss Function')
  plt.savefig("loss.eps", format = 'eps')

  plt.figure()
  plt.plot(c_rec)
  plt.title('c variable')
  plt.savefig("c.png")

  print(loss_rec)

with open('pnl.json', 'w') as f:
    json.dump(pnl, f)

plt.hist([p['Average'] for p in pnl])

print("Overall Profit:", np.round(np.mean([result['Gain'] for result in pnl]),2))
print("Average Profit:", np.round(np.mean([result['Average'] for result in pnl]),2))
print("gains_perc:", np.round(np.mean([result['gains_perc'] for result in pnl]),2))
print("Best:", np.round(np.mean([result['Best'] for result in pnl]),2))
print("Worst:", np.round(np.mean([result['Worst'] for result in pnl]),2))
print("sharp_ratio:", np.round(np.mean([result['sharp_ratio'] for result in pnl]),4))
print("sortino_ratio:", np.round(np.mean([result['sortino_ratio'] for result in pnl]),4))
# Out:
# tensor([ 34.0583,  37.4143,  24.8108,   8.2692,  43.5537,  33.9000,  33.6305,
#          32.4731,  20.7474,  40.7042,  37.5841,  50.5678,  47.0338,  -1.6782,
#          37.3547,  33.2395,  40.8718,  30.7774,   6.4745,  30.8772,  37.9621,
#          15.9231,  28.6300,  41.9930,  39.8467,  46.0733, -16.0760,   7.7082,
#          46.0553,  41.6302]) tensor([161.3575, 168.0952, 162.8521, 256.1905, 154.4932, 194.8300, 181.9038,
#         160.7874, 180.5376, 194.3519, 159.8380, 150.5769, 151.8811, 159.4953,
#         164.8727, 159.5488, 173.2773, 152.4669, 179.7041, 159.2946, 170.1451,
#         190.2003, 209.4785, 163.2582, 194.5710, 155.6705, 501.5909, 198.5215,
#         151.4404, 158.9649])
# Toal Gain: -1.9946775833333277 Total Cost: 4.8188645986916665
# {'Gain': -817.6250618429979, 'Best': 3045.0, 'Worst': -5107.17, 'Average': -6.81, 'loss_perc': 40.0, 'gains_perc': 60.0, 'sharp_ratio': -0.042, 'sortino_ratio': -0.04}
# Trial: 0
# Test at Epoch 0
# Toal Gain: -38.61031465537988 Total Cost: 20.70385930420082
# {'Gain': -7117.7008751496805, 'Best': 428.4, 'Worst': -710.81, 'Average': -59.31, 'loss_perc': 60.83, 'gains_perc': 39.17, 'sharp_ratio': -1.522, 'sortino_ratio': -2.01}
# Test at Epoch 10
# Toal Gain: 8.509423478068749 Total Cost: 1.5165119444064314
# {'Gain': 839.1493840394777, 'Best': 837.13, 'Worst': -1734.37, 'Average': 6.99, 'loss_perc': 35.0, 'gains_perc': 65.0, 'sharp_ratio': 0.18, 'sortino_ratio': 0.138}
# Test at Epoch 20
# Toal Gain: 10.220263584328206 Total Cost: 1.7653945778307285
# {'Gain': 1014.5842807796979, 'Best': 995.4, 'Worst': -2103.11, 'Average': 8.45, 'loss_perc': 35.83, 'gains_perc': 64.17, 'sharp_ratio': 0.177, 'sortino_ratio': 0.138}
# Test at Epoch 30
# Toal Gain: 10.60549620644566 Total Cost: 1.8734476019883763
# {'Gain': 1047.8458325348738, 'Best': 1038.93, 'Worst': -2231.45, 'Average': 8.73, 'loss_perc': 35.83, 'gains_perc': 64.17, 'sharp_ratio': 0.172, 'sortino_ratio': 0.134}
# Test at Epoch 40
# Toal Gain: 10.759440931908083 Total Cost: 1.934645490366627
# {'Gain': 1058.9754529849738, 'Best': 1059.39, 'Worst': -2294.98, 'Average': 8.82, 'loss_perc': 35.83, 'gains_perc': 64.17, 'sharp_ratio': 0.169, 'sortino_ratio': 0.132}
# Test at Epoch 50
# Toal Gain: 10.838488689609042 Total Cost: 1.9983180534742246
# {'Gain': 1060.8204763361778, 'Best': 1075.59, 'Worst': -2349.5, 'Average': 8.84, 'loss_perc': 35.83, 'gains_perc': 64.17, 'sharp_ratio': 0.165, 'sortino_ratio': 0.129}
# Test at Epoch 60
# Toal Gain: 10.848811708935942 Total Cost: 2.0040786625888733
132045031, -0.006124183535575867, -0.006219132337719202, -0.006314142141491175, -0.006409211549907923, -0.006504339165985584, -0.006599523592740297, -0.0066947634331882, -0.00679005729034543, -0.006885404232889414, -0.006980803329497576, -0.007076253183186054, -0.007171752396970987, -0.007267300505191088, -0.0073628961108624935, -0.00745853828266263, -0.007554226089268923, -0.007649958599358797, -0.007745734881609678, -0.007841554470360279, -0.007937416434288025, -0.008033319376409054]
# Trial: 1
# Test at Epoch 0
# Toal Gain: 7.6029954855412765 Total Cost: 20.74037397232382
# {'Gain': -1576.4854184139044, 'Best': 1390.73, 'Worst': -451.59, 'Average': -13.14, 'loss_perc': 51.67, 'gains_perc': 48.33, 'sharp_ratio': -0.293, 'sortino_ratio': -0.588}
# Test at Epoch 10
# Toal Gain: 7.717465169012441 Total Cost: 1.6300866225324888
# {'Gain': 730.4854255775939, 'Best': 830.57, 'Worst': -1744.26, 'Average': 6.09, 'loss_perc': 34.17, 'gains_perc': 65.83, 'sharp_ratio': 0.156, 'sortino_ratio': 0.118}
# Test at Epoch 20
# Toal Gain: 9.452788888951314 Total Cost: 1.9826956639259454
# {'Gain': 896.4111870030451, 'Best': 1008.88, 'Worst': -2133.62, 'Average': 7.47, 'loss_perc': 35.0, 'gains_perc': 65.0, 'sharp_ratio': 0.154, 'sortino_ratio': 0.119}
# Test at Epoch 30
# Toal Gain: 9.902887388332896 Total Cost: 2.106938067287265
# {'Gain': 935.5139185254764, 'Best': 1060.03, 'Worst': -2258.01, 'Average': 7.8, 'loss_perc': 35.0, 'gains_perc': 65.0, 'sharp_ratio': 0.152, 'sortino_ratio': 0.117}
# Test at Epoch 40
# Toal Gain: 10.039188913823276 Total Cost: 2.197236943967805
# {'Gain': 941.0342363826558, 'Best': 1083.23, 'Worst': -2335.01, 'Average': 7.84, 'loss_perc': 35.0, 'gains_perc': 65.0, 'sharp_ratio': 0.148, 'sortino_ratio': 0.114}
# Test at Epoch 50
# Toal Gain: 10.119338980341702 Total Cost: 2.1503047380283573
# {'Gain': 956.2841090776018, 'Best': 1082.65, 'Worst': -2307.36, 'Average': 7.97, 'loss_perc': 35.0, 'gains_perc': 65.0, 'sharp_ratio': 0.152, 'sortino_ratio': 0.117}
# Test at Epoch 60
# Toal Gain: 10.14560769958853 Total Cost: 2.184171339561006
# {'Gain': 955.3723632033041, 'Best': 1088.81, 'Worst': -2333.11, 'Average': 7.96, 'loss_perc': 35.0, 'gains_perc': 65.0, 'sharp_ratio': 0.15, 'sortino_ratio': 0.116}
# Test at Epoch 70
# Toal Gain: 10.121995725832626 Total Cost: 2.2300765421998574
# {'Gain': 947.0303020359318, 'Best': 1094.21, 'Worst': -2366.15, 'Average': 7.89, 'loss_perc': 35.0, 'gains_perc': 65.0, 'sharp_ratio': 0.147, 'sortino_ratio': 0.113}
# Test at Epoch 80
# Toal Gain: 10.1548535530461 Total Cost: 2.2035917729102352
# {'Gain': 954.151413616304, 'Best': 1091.88, 'Worst': -2348.32, 'Average': 7.95, 'loss_perc': 35.0, 'gains_perc': 65.0, 'sharp_ratio': 0.149, 'sortino_ratio': 0.115}
# Toal Gain: 8.977983517516028 Total Cost: 1.5900151473918636
# {'Gain': 886.5562044148995, 'Best': 1105.65, 'Worst': -1656.51, 'Average': 7.39, 'loss_perc': 35.83, 'gains_perc': 64.17, 'sharp_ratio': 0.187, 'sortino_ratio': 0.155}
# Test at Epoch 20
# Toal Gain: 9.892689096013331 Total Cost: 1.8780038168235051
# {'Gain': 961.7622335027788, 'Best': 1192.5, 'Worst': -2009.46, 'Average': 8.01, 'loss_perc': 34.17, 'gains_perc': 65.83, 'sharp_ratio': 0.168, 'sortino_ratio': 0.134}
# Test at Epoch 30
# Toal Gain: 9.992390153391447 Total Cost: 2.0402575776580476
# {'Gain': 954.2559090880085, 'Best': 1213.55, 'Worst': -2167.09, 'Average': 7.95, 'loss_perc': 34.17, 'gains_perc': 65.83, 'sharp_ratio': 0.156, 'sortino_ratio': 0.123}
# Test at Epoch 40
# Toal Gain: 9.99661387726198 Total Cost: 2.117312497113393
# {'Gain': 945.5161656178302, 'Best': 1220.78, 'Worst': -2237.08, 'Average': 7.88, 'loss_perc': 34.17, 'gains_perc': 65.83, 'sharp_ratio': 0.15, 'sortino_ratio': 0.118}
# Test at Epoch 50
# Toal Gain: 10.085222552538168 Total Cost: 2.0831729163756996
# {'Gain': 960.2459563394965, 'Best': 1222.27, 'Worst': -2218.23, 'Average': 8.0, 'loss_perc': 35.0, 'gains_perc': 65.0, 'sharp_ratio': 0.154, 'sortino_ratio': 0.122}
# Test at Epoch 60
# Toal Gain: 9.95728331141623 Total Cost: 2.1822761638843837
# {'Gain': 933.0008577038218, 'Best': 1224.89, 'Worst': -2290.69, 'Average': 7.78, 'loss_perc': 34.17, 'gains_perc': 65.83, 'sharp_ratio': 0.145, 'sortino_ratio': 0.114}
# Test at Epoch 70
# Toal Gain: 10.079319386853415 Total Cost: 2.1131572743780014
# {'Gain': 955.9394534970504, 'Best': 1224.18, 'Worst': -2242.81, 'Average': 7.97, 'loss_perc': 35.0, 'gains_perc': 65.0, 'sharp_ratio': 0.152, 'sortino_ratio': 0.12}
# Test at Epoch 80
# Toal Gain: 10.009975300275858 Total Cost: 2.1519105868810176
# {'Gain': 942.9677656073814, 'Best': 1224.96, 'Worst': -2270.38, 'Average': 7.86, 'loss_perc': 34.17, 'gains_perc': 65.83, 'sharp_ratio': 0.148, 'sortino_ratio': 0.116}
# Test at Epoch 90
# Toal Gain: 10.098024744600647 Total Cost: 2.09146450763236
# {'Gain': 960.7872284361956, 'Best': 1223.46, 'Worst': -2227.97, 'Average': 8.01, 'loss_perc': 35.0, 'gains_perc': 65.0, 'sharp_ratio': 0.153, 'sortino_ratio': 0.122}
# Done Training
# Toal Gain: 9.995859481785327 Total Cost: 2.16762322843057
# Result After Training:
# {'Gain': 939.3883504025697, 'Best': 1225.07, 'Worst': -2282.16, 'Average': 7.83, 'loss_perc': 34.17, 'gains_perc': 65.83, 'sharp_ratio': 0.147, 'sortino_ratio': 0.115}
00318373111076653, -0.003250058041885495, -0.0033166296780109406, -0.0033834425266832113, -0.003450492862612009, -0.0035177774261683226, -0.0035852929577231407, -0.0036530359648168087, -0.003721003420650959, -0.003789192298427224, -0.003857599338516593, -0.003926221746951342, -0.003995056729763746, -0.004064101260155439, -0.0041333530098199844, -0.00420280871912837, -0.00427246605977416, -0.004342322237789631, -0.004412374924868345, -0.004482621792703867, -0.004553060047328472, -0.0046236878260970116]
# Trial: 5
# Test at Epoch 0
# Toal Gain: 7.105220801270084 Total Cost: 20.482915411173334
# {'Gain': -1605.3233531883911, 'Best': 614.74, 'Worst': -691.58, 'Average': -13.38, 'loss_perc': 52.5, 'gains_perc': 47.5, 'sharp_ratio': -0.325, 'sortino_ratio': -0.477}
# Test at Epoch 10
# Toal Gain: 10.34204822502513 Total Cost: 1.4284354195161122
# {'Gain': 1069.6335366610822, 'Best': 903.28, 'Worst': -1493.82, 'Average': 8.91, 'loss_perc': 36.67, 'gains_perc': 63.33, 'sharp_ratio': 0.242, 'sortino_ratio': 0.206}
# Test at Epoch 20
# Toal Gain: 12.630102454746092 Total Cost: 1.6695423131522622
# {'Gain': 1315.2672169912596, 'Best': 1083.44, 'Worst': -1819.82, 'Average': 10.96, 'loss_perc': 35.83, 'gains_perc': 64.17, 'sharp_ratio': 0.241, 'sortino_ratio': 0.202}
# Test at Epoch 30
# Toal Gain: 13.248200569093155 Total Cost: 1.7846924682431913
# {'Gain': 1375.6209721019957, 'Best': 1135.46, 'Worst': -1947.73, 'Average': 11.46, 'loss_perc': 35.83, 'gains_perc': 64.17, 'sharp_ratio': 0.236, 'sortino_ratio': 0.198}
# Test at Epoch 40
# Toal Gain: 13.500482154011642 Total Cost: 1.8467226020820542
# {'Gain': 1398.4511462315495, 'Best': 1156.65, 'Worst': -2007.93, 'Average': 11.65, 'loss_perc': 35.83, 'gains_perc': 64.17, 'sharp_ratio': 0.233, 'sortino_ratio': 0.195}
# Test at Epoch 50
# Toal Gain: 13.594116852844328 Total Cost: 1.8780449401951411
# {'Gain': 1405.9286295179013, 'Best': 1165.55, 'Worst': -2036.21, 'Average': 11.72, 'loss_perc': 35.83, 'gains_perc': 64.17, 'sharp_ratio': 0.231, 'sortino_ratio': 0.193}
# Test at Epoch 60
# Toal Gain: 13.59048484264398 Total Cost: 1.8315323715161265
# {'Gain': 1411.0742965353427, 'Best': 1161.05, 'Worst': -2007.13, 'Average': 11.76, 'loss_perc': 35.83, 'gains_perc': 64.17, 'sharp_ratio': 0.235, 'sortino_ratio': 0.197}
# Test at Epoch 70
# Toal Gain: 13.606736251209387 Total Cost: 1.8468061306370904
# {'Gain': 1411.1916144686752, 'Best': 1163.73, 'Worst': -2019.18, 'Average': 11.76, 'loss_perc': 35.83, 'gains_perc': 64.17, 'sharp_ratio': 0.234, 'sortino_ratio': 0.195}
# Test at Epoch 80
# Toal Gain: 13.62705147885178 Total Cost: 1.8547028888435284
# {'Gain': 1412.6818308009906, 'Best': 1164.97, 'Worst': -2024.37, 'Average': 11.77, 'loss_perc': 35.83, 'gains_perc': 64.17, 'sharp_ratio': 0.234, 'sortino_ratio': 0.195}
# Test at Epoch 10
# Toal Gain: 5.447653070287447 Total Cost: 1.4965543987314802
# {'Gain': 474.1318405867151, 'Best': 980.47, 'Worst': -1713.1, 'Average': 3.95, 'loss_perc': 37.5, 'gains_perc': 62.5, 'sharp_ratio': 0.099, 'sortino_ratio': 0.081}
# Test at Epoch 20
# Toal Gain: 6.4759115503743185 Total Cost: 1.8365086677282116
# {'Gain': 556.7283459175328, 'Best': 1127.15, 'Worst': -2115.0, 'Average': 4.64, 'loss_perc': 38.33, 'gains_perc': 61.67, 'sharp_ratio': 0.093, 'sortino_ratio': 0.077}
# Test at Epoch 30
# Toal Gain: 6.785664907906736 Total Cost: 1.9294833045116462
# {'Gain': 582.7417924074102, 'Best': 1163.07, 'Worst': -2231.24, 'Average': 4.86, 'loss_perc': 38.33, 'gains_perc': 61.67, 'sharp_ratio': 0.093, 'sortino_ratio': 0.076}
# Test at Epoch 40
# Toal Gain: 6.9019381564571445 Total Cost: 1.9651997587747931
# {'Gain': 592.4086077218828, 'Best': 1175.96, 'Worst': -2275.44, 'Average': 4.94, 'loss_perc': 38.33, 'gains_perc': 61.67, 'sharp_ratio': 0.093, 'sortino_ratio': 0.076}
# Test at Epoch 50
# Toal Gain: 6.893109976685548 Total Cost: 2.015591897579876
# {'Gain': 585.3021694926805, 'Best': 1186.0, 'Worst': -2317.94, 'Average': 4.88, 'loss_perc': 38.33, 'gains_perc': 61.67, 'sharp_ratio': 0.09, 'sortino_ratio': 0.073}
# Test at Epoch 60
# Toal Gain: 6.898520498071044 Total Cost: 2.0238082575026777
# {'Gain': 584.9654688682044, 'Best': 1188.05, 'Worst': -2326.26, 'Average': 4.87, 'loss_perc': 38.33, 'gains_perc': 61.67, 'sharp_ratio': 0.09, 'sortino_ratio': 0.073}
# Test at Epoch 70
# Toal Gain: 6.8063181584887165 Total Cost: 2.07783840324111
# {'Gain': 567.417570629713, 'Best': 1195.63, 'Worst': -2364.88, 'Average': 4.73, 'loss_perc': 38.33, 'gains_perc': 61.67, 'sharp_ratio': 0.086, 'sortino_ratio': 0.07}
# Test at Epoch 80
# Toal Gain: 6.8931403077324145 Total Cost: 2.0340722379860976
# {'Gain': 583.0881683695569, 'Best': 1189.96, 'Worst': -2334.98, 'Average': 4.86, 'loss_perc': 38.33, 'gains_perc': 61.67, 'sharp_ratio': 0.089, 'sortino_ratio': 0.073}
# Test at Epoch 90
# Toal Gain: 6.911344829072967 Total Cost: 2.024869906362553
# {'Gain': 586.3769907252498, 'Best': 1189.03, 'Worst': -2328.73, 'Average': 4.89, 'loss_perc': 38.33, 'gains_perc': 61.67, 'sharp_ratio': 0.09, 'sortino_ratio': 0.073}
# Done Training
# Toal Gain: 6.92485550306385 Total Cost: 2.0224864063343073
# Result After Training:
# {'Gain': 588.2842916075458, 'Best': 1188.99, 'Worst': -2326.89, 'Average': 4.9, 'loss_perc': 38.33, 'gains_perc': 61.67, 'sharp_ratio': 0.09, 'sortino_ratio': 0.074}
# Test at Epoch 40
# Toal Gain: 10.541536638709642 Total Cost: 1.8587618267772579
# {'Gain': 1041.932977431887, 'Best': 1111.8, 'Worst': -2282.1, 'Average': 8.68, 'loss_perc': 33.33, 'gains_perc': 66.67, 'sharp_ratio': 0.166, 'sortino_ratio': 0.126}
# Test at Epoch 50
# Toal Gain: 10.573653599739478 Total Cost: 1.9028779620073044
# {'Gain': 1040.4930765278611, 'Best': 1117.13, 'Worst': -2320.95, 'Average': 8.67, 'loss_perc': 33.33, 'gains_perc': 66.67, 'sharp_ratio': 0.163, 'sortino_ratio': 0.124}
# Test at Epoch 60
# Toal Gain: 10.587896502930928 Total Cost: 1.916876262477321
# {'Gain': 1040.5224288544332, 'Best': 1119.24, 'Worst': -2333.68, 'Average': 8.67, 'loss_perc': 33.33, 'gains_perc': 66.67, 'sharp_ratio': 0.162, 'sortino_ratio': 0.123}
# Test at Epoch 70
# Toal Gain: 10.635557004142235 Total Cost: 1.87199384241588
# {'Gain': 1051.6275794071628, 'Best': 1119.07, 'Worst': -2303.44, 'Average': 8.76, 'loss_perc': 33.33, 'gains_perc': 66.67, 'sharp_ratio': 0.166, 'sortino_ratio': 0.126}
# Test at Epoch 80
# Toal Gain: 10.608316428784313 Total Cost: 1.887891265428847
# {'Gain': 1046.4510196026554, 'Best': 1119.29, 'Worst': -2315.28, 'Average': 8.72, 'loss_perc': 33.33, 'gains_perc': 66.67, 'sharp_ratio': 0.164, 'sortino_ratio': 0.125}
# Test at Epoch 90
# Toal Gain: 10.619883397166111 Total Cost: 1.8803765373508508
# {'Gain': 1048.7408231778304, 'Best': 1119.81, 'Worst': -2310.96, 'Average': 8.74, 'loss_perc': 33.33, 'gains_perc': 66.67, 'sharp_ratio': 0.165, 'sortino_ratio': 0.125}
# Done Training
# Toal Gain: 10.593158583205872 Total Cost: 1.922329459671686
# Result After Training:
# {'Gain': 1040.4994948241028, 'Best': 1120.25, 'Worst': -2339.47, 'Average': 8.67, 'loss_perc': 33.33, 'gains_perc': 66.67, 'sharp_ratio': 0.162, 'sortino_ratio': 0.123}
# [9.093189239501953, 0.00010000001202570274, 0.0001608180027687922, 0.00020256706920918077, 0.00023201783187687397, 0.00025248914607800543, 0.00026593185612000525, 0.0002736249298322946, 0.0002764704404398799, 0.00027513879467733204, 0.00027014812803827226, 0.00026191119104623795, 0.0002507648023311049, 0.00023698914446868002, 0.0002208210644312203, 0.0002024634013650939, 0.0001820917968871072, 0.00015985977370291948, 0.00013590259186457843, 0.0001103402319131419, 8.327975228894502e-05, 5.4817170166643336e-05, 2.5038967578439042e-05, -5.976633019599831e-06, -3.8158636016305536e-05, -7.144242408685386e-05, -0.00010576900967862457, -0.00014108442701399326, -0.0001773391559254378, -0.00021448772167786956, -0.0002524882147554308, -0.00029130204347893596, -0.0003308934683445841, -0.0003712295147124678, -0.00041227953624911606, -0.0004540151567198336, -0.0004964100080542266, -0.0005394395557232201, -0.0005830808659084141, -0.0006273126346059144, -0.0006721149547956884,
002253564540296793, -0.002307748654857278, -0.002362195635214448, -0.0024169019889086485, -0.002471864689141512, -0.0025270807091146708, -0.002582546789199114, -0.0026382599025964737, -0.0026942172553390265, -0.0027504160534590483, -0.0028068535029888153, -0.0028635268099606037, -0.0029204331804066896, -0.0029775702860206366, -0.0030349353328347206, -0.0030925259925425053, -0.0031503397040069103, -0.0032083741389214993, -0.0032666269689798355, -0.0033250958658754826, -0.0033837787341326475, -0.003442673245444894, -0.003501777071505785, -0.0035610883496701717, -0.0036206047516316175]
# Trial: 9
# Test at Epoch 0
# Toal Gain: 9.236816996027134 Total Cost: 18.854510884280234
# {'Gain': -1154.123266590373, 'Best': 693.94, 'Worst': -648.42, 'Average': -9.62, 'loss_perc': 59.17, 'gains_perc': 40.83, 'sharp_ratio': -0.261, 'sortino_ratio': -0.436}
# Test at Epoch 10
# Toal Gain: 7.4344516608754345 Total Cost: 1.4918100579878555
# {'Gain': 713.1169923465086, 'Best': 916.49, 'Worst': -1684.43, 'Average': 5.94, 'loss_perc': 35.0, 'gains_perc': 65.0, 'sharp_ratio': 0.154, 'sortino_ratio': 0.121}
# Test at Epoch 20
# Toal Gain: 9.100700552753505 Total Cost: 1.7122170512485513
# {'Gain': 886.6180201805952, 'Best': 1093.17, 'Worst': -2062.31, 'Average': 7.39, 'loss_perc': 34.17, 'gains_perc': 65.83, 'sharp_ratio': 0.154, 'sortino_ratio': 0.12}
# Test at Epoch 30
# Toal Gain: 9.486598950996354 Total Cost: 1.8188072480896225
# {'Gain': 920.1350043488081, 'Best': 1143.3, 'Worst': -2201.69, 'Average': 7.67, 'loss_perc': 34.17, 'gains_perc': 65.83, 'sharp_ratio': 0.15, 'sortino_ratio': 0.116}
# Test at Epoch 40
# Toal Gain: 9.624053501061878 Total Cost: 1.8451748667096066
# {'Gain': 933.4654361222731, 'Best': 1159.53, 'Worst': -2244.19, 'Average': 7.78, 'loss_perc': 34.17, 'gains_perc': 65.83, 'sharp_ratio': 0.15, 'sortino_ratio': 0.116}
# Test at Epoch 50
# Toal Gain: 9.681762786518096 Total Cost: 1.864812128713281
# ...
# Trial: 47
# Test at Epoch 0
# Toal Gain: -24.410865579943387 Total Cost: 20.397387279637616
# {'Gain': -5376.990343149717, 'Best': 296.8, 'Worst': -542.4, 'Average': -44.81, 'loss_perc': 56.67, 'gains_perc': 43.33, 'sharp_ratio': -1.557, 'sortino_ratio': -2.283}
# Test at Epoch 10
# Toal Gain: 8.641160188109108 Total Cost: 1.4371704831953194
# {'Gain': 864.4787645896549, 'Best': 1048.22, 'Worst': -1764.1, 'Average': 7.2, 'loss_perc': 36.67, 'gains_perc': 63.33, 'sharp_ratio': 0.177, 'sortino_ratio': 0.143}
# Test at Epoch 20
# Toal Gain: 10.33840962226317 Total Cost: 1.7537531820917502
# {'Gain': 1030.1587728205707, 'Best': 1199.33, 'Worst': -2180.99, 'Average': 8.58, 'loss_perc': 37.5, 'gains_perc': 62.5, 'sharp_ratio': 0.17, 'sortino_ratio': 0.137}
# Test at Epoch 30
# Toal Gain: 10.722849232809251 Total Cost: 1.8648418697503089
# {'Gain': 1062.960883567074, 'Best': 1240.08, 'Worst': -2316.37, 'Average': 8.86, 'loss_perc': 37.5, 'gains_perc': 62.5, 'sharp_ratio': 0.165, 'sortino_ratio': 0.133}
# Test at Epoch 40
# Toal Gain: 10.818411488910776 Total Cost: 1.9316343505869726
# {'Gain': 1066.4132565988566, 'Best': 1259.03, 'Worst': -2389.75, 'Average': 8.89, 'loss_perc': 37.5, 'gains_perc': 62.5, 'sharp_ratio': 0.161, 'sortino_ratio': 0.13}
# Test at Epoch 50
# Toal Gain: 10.900309039743384 Total Cost: 1.921984773895604
# {'Gain': 1077.3989119017342, 'Best': 1260.79, 'Worst': -2386.88, 'Average': 8.98, 'loss_perc': 37.5, 'gains_perc': 62.5, 'sharp_ratio': 0.163, 'sortino_ratio': 0.131}
# Test at Epoch 60
# Toal Gain: 10.939860264769777 Total Cost: 1.9005313723881656
# {'Gain': 1084.7194670857937, 'Best': 1258.07, 'Worst': -2370.92, 'Average': 9.04, 'loss_perc': 37.5, 'gains_perc': 62.5, 'sharp_ratio': 0.165, 'sortino_ratio': 0.133}
# Test at Epoch 70
# Toal Gain: 10.952285176403707 Total Cost: 1.8829824446910775
# {'Gain': 1088.3163278055151, 'Best': 1256.15, 'Worst': -2357.64, 'Average': 9.07, 'loss_perc': 37.5, 'gains_perc': 62.5, 'sharp_ratio': 0.166, 'sortino_ratio': 0.134}
# Test at Epoch 80
# Toal Gain: 10.924605635949781 Total Cost: 1.9411298913679471
# {'Gain': 1078.0170893498205, 'Best': 1265.42, 'Worst': -2406.21, 'Average': 8.98, 'loss_perc': 37.5, 'gains_perc': 62.5, 'sharp_ratio': 0.162, 'sortino_ratio': 0.13}
# Test at Epoch 90
# Toal Gain: 10.94127240447392 Total Cost: 1.91569657516471
# {'Gain': 1083.069099517105, 'Best': 1261.62, 'Worst': -2385.94, 'Average': 9.03, 'loss_perc': 37.5, 'gains_perc': 62.5, 'sharp_ratio': 0.164, 'sortino_ratio': 0.132}
# Done Training
# Toal Gain: 10.920810254887389 Total Cost: 1.947284757498268
# Result After Training:
# {'Gain': 1076.823059686695, 'Best': 1266.78, 'Worst': -2411.88, 'Average': 8.97, 'loss_perc': 37.5, 'gains_perc': 62.5, 'sharp_ratio': 0.161, 'sortino_ratio': 0.13}
# [6.403561115264893, 9.99999901978299e-05, 0.00015943970356602222, 0.0001989746670005843, 0.00022559540229849517, 0.000242745183641091, 0.00025245698634535074, 0.00025606900453567505, 0.00025452853878960013, 0.00024854190996848047, 0.0002386566047789529, 0.00022530990827362984, 0.00020885946287307888, 0.00018960339366458356, 0.00016779413272161037, 0.0001436482125427574, 0.00011735340376617387, 8.907403389457613e-05, 5.895502181374468e-05, 2.7125053748022765e-05, -6.300934273895109e-06, -4.121978781768121e-05, -7.753850513836369e-05, -0.00011517290840856731, -0.00015404656005557626, -0.00019408980733714998, -0.00023523904383182526, -0.00027743601822294295, -0.00032062726677395403, -0.0003647636331152171, -0.0004097997734788805, -0.00045569389476440847, -0.0005024073179811239, -0.0005499041872099042, -0.0005981513531
.005634792614728212, -0.005730397533625364, -0.005826061591506004, -0.0059217833913862705, -0.006017561070621014, -0.006113393697887659, -0.006209279410541058, -0.006305216811597347, -0.0064012049697339535, -0.006497242487967014, -0.006593327969312668, -0.0066894604824483395, -0.006785638630390167, -0.006881861947476864, -0.006978129036724567, -0.007074438501149416, -0.007170789875090122, -0.0072671822272241116, -0.007363614626228809, -0.007460086140781641, -0.007556595839560032, -0.007653143256902695, -0.0077497269958257675, -0.00784634705632925, -0.007943002507090569, -0.008039692416787148, -0.008136415854096413, -0.008233172819018364]
# Trial: 49
# Test at Epoch 0
# Toal Gain: -1.178457143758078 Total Cost: 20.561205950266093
# {'Gain': -2608.759571282901, 'Best': 796.7, 'Worst': -599.88, 'Average': -21.74, 'loss_perc': 56.67, 'gains_perc': 43.33, 'sharp_ratio': -0.547, 'sortino_ratio': -1.106}
# Test at Epoch 10
# Toal Gain: 7.451967578984178 Total Cost: 1.378514030210908
# {'Gain': 728.8144258527925, 'Best': 980.42, 'Worst': -1704.55, 'Average': 6.07, 'loss_perc': 35.0, 'gains_perc': 65.0, 'sharp_ratio': 0.152, 'sortino_ratio': 0.122}
# Test at Epoch 20
# Toal Gain: 8.627434819087693 Total Cost: 1.624789615383231
# {'Gain': 840.3174244445347, 'Best': 1061.95, 'Worst': -2073.15, 'Average': 7.0, 'loss_perc': 33.33, 'gains_perc': 66.67, 'sharp_ratio': 0.144, 'sortino_ratio': 0.112}
# Test at Epoch 30
# Toal Gain: 8.863933805802803 Total Cost: 1.7969390106595104
# {'Gain': 848.0393754171953, 'Best': 1087.43, 'Worst': -2254.17, 'Average': 7.07, 'loss_perc': 33.33, 'gains_perc': 66.67, 'sharp_ratio': 0.135, 'sortino_ratio': 0.103}
# Test at Epoch 40
# Toal Gain: 8.979996656691844 Total Cost: 1.8202737975227448
# {'Gain': 859.166743100292, 'Best': 1093.32, 'Worst': -2290.43, 'Average': 7.16, 'loss_perc': 33.33, 'gains_perc': 66.67, 'sharp_ratio': 0.134, 'sortino_ratio': 0.103}
# Test at Epoch 50
# Toal Gain: 9.007043904020536 Total Cost: 1.864670206636454
# {'Gain': 857.0848436860898, 'Best': 1097.53, 'Worst': -2330.83, 'Average': 7.14, 'loss_perc': 33.33, 'gains_perc': 66.67, 'sharp_ratio': 0.132, 'sortino_ratio': 0.101}
# Test at Epoch 60
# Toal Gain: 9.018060559651557 Total Cost: 1.8802138116060283
# {'Gain': 856.5416097654639, 'Best': 1098.93, 'Worst': -2344.83, 'Average': 7.14, 'loss_perc': 33.33, 'gains_perc': 66.67, 'sharp_ratio': 0.131, 'sortino_ratio': 0.1}
# Test at Epoch 70
# Toal Gain: 9.03585436005178 Total Cost: 1.8470027539987532
# {'Gain': 862.6621927263642, 'Best': 1097.31, 'Worst': -2321.26, 'Average': 7.19, 'loss_perc': 33.33, 'gains_perc': 66.67, 'sharp_ratio': 0.133, 'sortino_ratio': 0.102}
# Test at Epoch 80
# Toal Gain: 9.028657102177128 Total Cost: 1.8792778181106267
